# %% [markdown]
# # **Do Connections Really Matter?**
#
# ### Group Members:
# - Winston Cai: did absolutely nothing(0 hours, 0 minutes, 0 seconds)
# - Ricky Jung: did absolutely nothing(0 hours, 0 minutes, 0 seconds)
# - Chris Spencer: everything starting from project backround up until interpretation and conclusion(12 hours)
# - Carolyn Zhou: Abstract, Interpreatation and Conlusuon, and parts of the linear regression model(7 hours)

# %% [markdown]
# ## Abstract (5 points)
# Social connections are evidently of utmost interest when studying socioeconomic status, as they indicate and influence the kinds of opportunities and institutions an individual will have access to. Our project aims to study and model whether or not connections between lower and higher income communities can help facilitate social and economic mobility. We studied this phenomenon by specifically narrowing in on students attending universities in California, as college is the time when a large majority of individuals (particularly students) first begin to make connections with peers and outside individuals. We chose 2 modeling techniques: simple linear regression and clustering, and found that both showed that there was a strong relationship between 1. economic connectedness for individuals with high socioeconomic standings and 2. exposure to these individuals from those with a low socioeconomic standing. From this we learned that exposure to individuals of higher socioeconomic standing does have a significant impact on economic connectedness and social mobility.

# %% [markdown]
# ## Project Background (5 points)
# When analyzing potential causes and solutions to class mobility in America, it is important to take into cosideration who they are surrounded by and who they know. Our goal is to discover how much this may impact an indivdual's future. More specifically, we want to see how this starts to play out in California colleges, as most people start meeting real professional connections with their peers starting then. Additionally, many colleges have resources, some of which may have superior ones depending on the funding, reputation(Stanford vs CCC), and other factors.

# %% [markdown]
# ## Project Objective (5 points)
# The purpose of this project is to discover if having connections to higher-income individuals (friends, family, etc) can increase their socioeconomic status.

# %% [markdown]
# ## Data Description ( 5 points)
# Sourced from Meta, formerly Facebook, this data was collected with aims to quantify connections to individuals of high socioeconomic standing. Each data point represents a university. Later, during the data cleaning stage, we will focus only on colleges in California. Even still, each data point still represents a college in the state of California.
# ![](attachment:d6a906b1-1227-4e11-84ab-85051b91cd47.png)

# %% [markdown]
# ## Data Cleaning (5 points)

# %%
# import main packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

import warnings
warnings.filterwarnings('ignore')

# %%
# Load US college data
us_college_data = pd.read_csv("social_capital_college.csv")
county_data = pd.read_csv("social_capital_county.csv")

# %%
# Merge datasets
merged = us_college_data.merge(county_data, on="county")
merged.head()
# Out:
#    college                                       college_name    zip  county  \
# 0   100200                           Alabama A & M University  35762    1089
# 1   103300                                 Oakwood University  35896    1089
# 2   105500                University of Alabama in Huntsville  35899    1089
# 3   526000  J. F. Drake State Community and Technical College  35811    1089
# 4   100300                                Faulkner University  36109    1101
#
#    mean_students_per_cohort  ec_own_ses_college  ec_own_ses_se_college  \
# 0                943.666667             0.85678                0.02233
# 1                       NaN             1.47346                0.03065
# 2                636.333333             1.41845                0.02850
# 3                       NaN                 NaN                    NaN
# 4                227.666667             1.30964                0.04869
#
# ...

# %%
# Create new df that only contains colleges in California
california_colleges = merged.query('county_name.str.contains("California")', engine='python')
california_colleges.head()
# Out:
#      college                            college_name    zip  county  \
# 100   111100                   Allan Hancock College  93454    6083
# 101   128500              Santa Barbara City College  93109    6083
# 102   132000  University of California-Santa Barbara  93106    6083
# 103   134100                        Westmont College  93108    6083
# 104   111300                 Antelope Valley College  93536    6037
#
#      mean_students_per_cohort  ec_own_ses_college  ec_own_ses_se_college  \
# 100               1220.000000             1.13665                0.02534
# 101               1827.000000             1.44700                0.02539
# 102               3450.333333             1.80382                0.01471
# 103                296.666667             1.87857                0.02474
# 104               1904.666667             1.01572                0.02544
#
#      ec_parent_ses_college  ec_parent_ses_se_college  ec_high_own_ses_college  \
# ...

# %%
def college_type(data):
    """This function uses regex to find 3 main different categories of 
    colleges and classifies them as either a UC, CSU, or CCC"""
    if "University of California-" in data:
        return "UC"
    elif "California State University-" in data:
        return "CSU"
    elif "Community College" in data:
        return "CCC"
    return "Other"
    
california_colleges['college_type'] = california_colleges['college_name'].apply(college_type)

# %% [markdown]
# # **Clustering**
# ##### We will now dive into clustering methods! Unlike most ML techniques you are familiar with, such as regression and classification techniques such as decision trees, clustering is `unsupervised` ML protocol. This means that the algorithm, when deployed, will sort each new input into a cluster, even without it being placed into one. `K-means clustering` is the most popular and most utilized. For those of you familiar with runtime complexities of algorithms, K-means clustering has a linear, or O(n), runtime (there are some disagreements as to how true that is in certain cases, but it is mostly linear). To explain more simply, as the data set grows and more entries are inputted, the amount of time it takes for the algo to run increases in a linear fashion. Here is a quintessential, but really great graph to help visualize runtime complexities:
# ![image.png](attachment:9c14b14a-5910-472d-8137-428f8e0efc8b.png)

# %% [markdown]
# ##### So how do we choose centers, or "cluster sites", as I like to call them? Here are the main steps:
# 1. "Randomly" choose K number of centers, or cluster sites
#     -  I put randomly in quotes because there is a method, called the elbow method, that can provide a much closer value for k than an arbitrary number, but we won't worry about that for now.
# 2. Make each cluster site a different color
# 3. Points closest to a certain cluster site should be the same color.
#     - We'll see how to do this more mathematically later>

# %% [markdown]
# ## Exploratory Data Analysis (20 points)

# %%
sns.scatterplot(data=california_colleges.query("college_type != 'Other'"),
                x='ec_own_ses_college',
                y='exposure_own_ses_college',
                hue='college_type')
# Out:
# <AxesSubplot:xlabel='ec_own_ses_college', ylabel='exposure_own_ses_college'>

# %% [markdown]
# ##### As you can already see, there are groupings forming; however, you can also notice that some points are encroaching on areas that they may not belong to.

# %%
without_labels = california_colleges.drop(["college_type", "college_name"], axis=1).dropna()
without_labels
# Out:
#       college    zip  county  mean_students_per_cohort  ec_own_ses_college  \
# 100    111100  93454    6083               1220.000000             1.13665
# 101    128500  93109    6083               1827.000000             1.44700
# 102    132000  93106    6083               3450.333333             1.80382
# 103    134100  93108    6083                296.666667             1.87857
# 104    111300  93536    6037               1904.666667             1.01572
# ...       ...    ...     ...                       ...                 ...
# 2397   770700  95370    6109               2879.000000             1.17845
# 2421   859700  95971    6063                179.000000             1.18067
# 2473  1167200  95482    6045                482.000000             0.79295
# 2487  1290700  96150    6017                340.666667             1.08800
# 2538  4111300  93245    6031                808.000000             1.03805
#
# ...

# %% [markdown]
# ## Modeling (20 points)

# %%
class Center():
    def __init__(self, data):
        """generates a random center inside the region bounded by the data"""        
        num_dimensions = data.shape[1]
        self.coordinates = np.array([0.0] * num_dimensions)
        for i in range(num_dimensions):
            min_value = np.min(data[:, i])
            max_value = np.max(data[:, i])            
            random_value = random.uniform(min_value, max_value)            
            self.coordinates[i] = random_value
    
    def __str__(self):
        return str(self.coordinates)

    def __repr__(self):
        return repr(self.coordinates)

    def dist(self, data_point):
        return np.sqrt(np.sum((self.coordinates - data_point)**2, axis = 1))

# %%
# Initializes 3 different centers using the same data
c1 = Center(without_labels[['ec_own_ses_college', 'exposure_own_ses_college']].values)
c2 = Center(without_labels[['ec_own_ses_college', 'exposure_own_ses_college']].values)
c3 = Center(without_labels[['ec_own_ses_college', 'exposure_own_ses_college']].values)

# %%
def plot_centers_and_black_data(without_labels, centers):
    """plots all of the included data as well as the cluster centers we created above."""
    sns.scatterplot(data=without_labels, x="ec_own_ses_college", y="exposure_own_ses_college",
                    color="black")
    for center in centers:
        plt.plot(center.coordinates[0], center.coordinates[1], '*', markersize=10)    
    plt.xlabel('ec_own_ses_college')
    plt.ylabel('exposure_own_ses_college')
    legend_text = ['site' + str(i) for i in range(1, len(centers) + 1)]
    legend_text.insert(0, 'data')
    plt.legend(legend_text)

# %%
plot_centers_and_black_data(without_labels, (c1, c2, c3))

# %%
def get_cluster_number(dists):
    """identifies how many clusters are created"""
    return np.where(dists == np.min(dists))[0][0]

# %%
without_labels["dist1"] = c1.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist2"] = c2.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist3"] = c3.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["cluster"] = without_labels[["dist1", "dist2", "dist3"]].apply(get_cluster_number, axis=1)
without_labels["cluster"].value_counts()
# Out:
# 1    79
# 0    43
# 2    37
# Name: cluster, dtype: int64

# %% [markdown]
# ##### If, after running the above cell, you do not get 3 different clusters, rerun all cells starting from the one under the Center class.

# %%
def plot_centers_and_colorized_data(without_labels, centers):
    """Plots each data point that is colorized based on the cluster site
    it was randomly assigned."""
    current_palette = sns.color_palette()[0:len(centers)]
    sns.scatterplot(data=without_labels, x="ec_own_ses_college", y="exposure_own_ses_college",
                    hue="cluster",
                    palette=current_palette)  
    for center in centers:
        plt.plot(center.coordinates[0], center.coordinates[1], '*', markersize=10)
    plt.xlabel('ec_own_ses_college')
    plt.ylabel('exposure_own_ses_college')
    legend_text = ['cluster' + str(i) for i in range(1, len(centers) + 1)]
    plt.legend(legend_text)

# %%
plot_centers_and_colorized_data(without_labels, (c1, c2, c3))

# %%
average_c1_length = np.mean(without_labels[without_labels["cluster"] == 0])["ec_own_ses_college"]
average_c1_width = np.mean(without_labels[without_labels["cluster"] == 0])["exposure_own_ses_college"]
c1.coordinates = (average_c1_length, average_c1_width)

average_c2_length = np.mean(without_labels[without_labels["cluster"] == 1])["ec_own_ses_college"]
average_c2_width = np.mean(without_labels[without_labels["cluster"] == 1])["exposure_own_ses_college"]
c2.coordinates = (average_c2_length, average_c2_width)

average_c3_length = np.mean(without_labels[without_labels["cluster"] == 2])["ec_own_ses_college"]
average_c3_width = np.mean(without_labels[without_labels["cluster"] == 2])["exposure_own_ses_college"]
c3.coordinates = (average_c3_length, average_c3_width)

average_c1_length, average_c1_width
# Out:
# (1.2305267418604655, 1.3050283767441861)

# %% [markdown]
# # **Mathematically Punitive**
# ##### The above `length` and `width` values are found by grouping all data points who are part of the same cluster we assigned earlier and taking their average value. We then assign the newly found averages to the coordinates of the 3 different clusters. For those of you interested in the most fun part, here is the formula expressed mathematically:
# $$argmin \sum_{i=1}^{k}\sum_{x \in S_{i}}||x- \mu_{i}||^2 = argmin [dist(c_{i}, x)^2]$$

# %%
plot_centers_and_black_data(without_labels, (c1, c2, c3))

# %%
without_labels["dist1"] = c1.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist2"] = c2.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist3"] = c3.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["cluster"] = without_labels[["dist1", "dist2", "dist3"]].apply(get_cluster_number, axis = 1)

# %%
plot_centers_and_colorized_data(without_labels, (c1, c2, c3))

# %%
average_c1_length = np.mean(without_labels[without_labels["cluster"] == 0])["ec_own_ses_college"]
average_c1_width = np.mean(without_labels[without_labels["cluster"] == 0])["exposure_own_ses_college"]
c1.coordinates = (average_c1_length, average_c1_width)

average_c2_length = np.mean(without_labels[without_labels["cluster"] == 1])["ec_own_ses_college"]
average_c2_width = np.mean(without_labels[without_labels["cluster"] == 1])["exposure_own_ses_college"]
c2.coordinates = (average_c2_length, average_c2_width)

average_c3_length = np.mean(without_labels[without_labels["cluster"] == 2])["ec_own_ses_college"]
average_c3_width = np.mean(without_labels[without_labels["cluster"] == 2])["exposure_own_ses_college"]
c3.coordinates = (average_c3_length, average_c3_width)

average_c1_length, average_c1_width
# Out:
# (1.2458483370370372, 1.3108142611111115)

# %%
plot_centers_and_black_data(without_labels, (c1, c2, c3))

# %%
without_labels["dist1"] = c1.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist2"] = c2.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist3"] = c3.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["cluster"] = without_labels[["dist1", "dist2", "dist3"]].apply(get_cluster_number, axis = 1)

# %%
plot_centers_and_colorized_data(without_labels, (c1, c2, c3))

# %%
average_c1_length = np.mean(without_labels[without_labels["cluster"] == 0])["ec_own_ses_college"]
average_c1_width = np.mean(without_labels[without_labels["cluster"] == 0])["exposure_own_ses_college"]
c1.coordinates = (average_c1_length, average_c1_width)

average_c2_length = np.mean(without_labels[without_labels["cluster"] == 1])["ec_own_ses_college"]
average_c2_width = np.mean(without_labels[without_labels["cluster"] == 1])["exposure_own_ses_college"]
c2.coordinates = (average_c2_length, average_c2_width)

average_c3_length = np.mean(without_labels[without_labels["cluster"] == 2])["ec_own_ses_college"]
average_c3_width = np.mean(without_labels[without_labels["cluster"] == 2])["exposure_own_ses_college"]
c3.coordinates = (average_c3_length, average_c3_width)

average_c1_length, average_c1_width
# Out:
# (1.2623031068965522, 1.3252072431034485)

# %%
plot_centers_and_black_data(without_labels, (c1, c2, c3))

# %%
without_labels["dist1"] = c1.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist2"] = c2.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist3"] = c3.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["cluster"] = without_labels[["dist1", "dist2", "dist3"]].apply(get_cluster_number, axis = 1)

# %%
plot_centers_and_colorized_data(without_labels, (c1, c2, c3))

# %%
average_c1_length = np.mean(without_labels[without_labels["cluster"] == 0])["ec_own_ses_college"]
average_c1_width = np.mean(without_labels[without_labels["cluster"] == 0])["exposure_own_ses_college"]
c1.coordinates = (average_c1_length, average_c1_width)

average_c2_length = np.mean(without_labels[without_labels["cluster"] == 1])["ec_own_ses_college"]
average_c2_width = np.mean(without_labels[without_labels["cluster"] == 1])["exposure_own_ses_college"]
c2.coordinates = (average_c2_length, average_c2_width)

average_c3_length = np.mean(without_labels[without_labels["cluster"] == 2])["ec_own_ses_college"]
average_c3_width = np.mean(without_labels[without_labels["cluster"] == 2])["exposure_own_ses_college"]
c3.coordinates = (average_c3_length, average_c3_width)

average_c1_length, average_c1_width
# Out:
# (1.2654335627118647, 1.329431018644068)

# %%
plot_centers_and_black_data(without_labels, (c1, c2, c3))

# %%
without_labels["dist1"] = c1.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist2"] = c2.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["dist3"] = c3.dist(without_labels[["ec_own_ses_college", "exposure_own_ses_college"]])
without_labels["cluster"] = without_labels[["dist1", "dist2", "dist3"]].apply(get_cluster_number, axis = 1)

# %%
plot_centers_and_colorized_data(without_labels, (c1, c2, c3))

# %% [markdown]
# ##### Notice how the graphs as well as their average `length` and `width` values virtually stop changing. We can conclude here. To reiterate what we did:
# 1. Randomly select three different cluster sites.
# 2. Assign each data point to one of these three cluster sites, creating clusters by mathematically calculating the euclidean distance.
# 3. Repeat these steps until the cluster sites stop changing and clustering variation is minimized.

# %% [markdown]
# # **Agglomerative Clustering**
# ##### This method of clustering starts off by treating each individual data point as it's own cluster. The algorithm then combines clusters that are similar together until one larger cluster is formed. Run the code below to see the difference. It may be subtle, but look closely at the clusters and points they contain!

# %%
from sklearn.cluster import AgglomerativeClustering
model = AgglomerativeClustering(n_clusters = 3, linkage='ward')
model.fit(without_labels.loc[:, ['ec_own_ses_college', 'exposure_own_ses_college']])
label = model.labels_

# %%
sns.scatterplot(data=without_labels, x='ec_own_ses_college', y='exposure_own_ses_college', hue=model.labels_).set_title('Agglomerative Clustering');

# %% [markdown]
# # **Linear Regression**

# %%
features = ['ec_own_ses_college']
X = without_labels.loc[:, features]
y = without_labels.loc[:, ['exposure_own_ses_college']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size=0.8)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

ss = StandardScaler()
X_train = pd.DataFrame( # turning scaled output (np.Array) back into DataFrame
         ss.fit_transform(X_train),
         columns=X_train.columns,
         index=X_train.index
         )
          
          
X_test = pd.DataFrame( # turning scaled output (np.Array) back into DataFrame
        ss.transform(X_test),
        columns=X_test.columns,
        index=X_test.index
        )


linreg = LinearRegression()
linreg.fit(X_train, y_train)


# out-of-sample prediction
lin_preds = linreg.predict(X_test)
np.mean(abs(lin_preds - y_test))
# Out:
# exposure_own_ses_college    0.039543
# dtype: float64

# %%
ax = sns.lmplot(data=without_labels, x='ec_own_ses_college', y='exposure_own_ses_college')
ax.set(xlabel="Baseline Economic Connectedness",
       ylabel="Mean exposure to high-SES individuals by college",
      title="Connections to High SES based on University")

# %%
x = without_labels["exposure_own_ses_college"]
y = without_labels["ec_own_ses_college"]
r = np.corrcoef(x, y)
r
# Out:
# array([[1.        , 0.99170874],
#        [0.99170874, 1.        ]])

# %% [markdown]
# ## Interpretation and Conclusions (20 points)
# 1. Address an economic question.  What do the answers mean? What advice would you give a decision maker on the basis of your results?  How might they allocate their resources differently or change their decisions with the results of your model?  Why should the reader care about your results?
#
# Recent social and development economics research has shown that upward economic mobility is facilitated by a wide variety of different influences and factors, some of which include academic and educational opportunities, geographical limitations, racial segregation, and access to healthcare and other infrastructures. Whether or not this applies to social networks is an important point of recent contention and study. When it comes to social networks, many communities are highly hierarchical and even insular, as higher income people tend to befriend other similarly high-income individuals. Similarly, impoverished individuals tend to mingle and reside within similarly impoverished communities.
# The economic question that our results best answer is restated in our project objective, which states that we aim to study whether or not connections to higher-income individuals can increase one’s socioeconomic status. We can see from our models, both for clustering and for linear regression, that there is a strong connection between economic connectedness for those of high socioeconomic status and mean exposure to said individuals from those of a lower status. Economic connectedness is a measure of the degree to which people of different socioeconomic statuses will interact and engage with one another. In our case, we can see that greater levels of social connection and inter-class interaction from those with higher status can result in greater economic mobility and connections from those with lower status.
# Based on the results we’ve achieved here, the best advice to any lower SES decision-maker seeking to lift themselves out of poverty or achieve higher levels of upward social and economic mobility would be to aim to make connections with individuals and communities from higher socioeconomic standings. Social networks are highly hierarchical, and people tend to stay within their own communities and befriend people with similar SESs. This is caused largely by factors such as race, location, etc. Despite this, our project focuses largely on Californian colleges, which are places where individuals from a wide variety of backgrounds and socioeconomic standings can congregate. As our project studies have shown, economic connectedness within colleges is very much significant in the conversation of upward socioeconomic mobility, and so any decision-maker in college would be wise to take advantage of their unique and advantageous environment and begin befriending and making connections with high SES individuals. This is a win-win situation, as even high SES individuals themselves can do the same and encourage further inter-class interactions between their higher-income communities and lower-income students.
#
#
# 2. Discuss caveats and / or reasons your results might be flawed.  No model is perfect, and understanding a model's imperfections is extremely important for the purpose of knowing how to interpret your results.  Often, we know the model output is wrong but we can assign a direction for its bias.  This helps to understand whether or not your answers are conservative.
# Shoot for 500 words for this section.
#
# When it comes to our models, there are a few flaws we need to consider regarding both our modeling techniques. For clustering (specifically k-means clustering, which we use in our project) can result in wildly varying results depending on how many clusters we have. Furthermore, the cluster centroids can be significantly influenced by outliers. Since our model did not involve removing outliers before clustering, this could potentially have had an impact on our results.
# Similar problems can also arise in our second technique: linear regression. Linear regression’s beauty lies in its simplicity, but said simplicity can also give rise to various issues. Since our models and graphs all display extremely strong relationships between variables, some of these problems might not be as severe. For example, while the assumption of linearity may be a problem for a relationship that doesn’t involve a linearly related independent and dependent variable, this one seems to do just fine regardless. However, there are still downsides such as sensitivity to outliers and over-simplicity.
# The main and immediate potential reason our results might be flawed is the comparison that we made between EC for high SES individuals and mean exposure to high SES individuals from low SES individuals. The main point of contention that our project is trying to study is whether or not increased social and economic connection causes an increase in social and economic mobility for those with a lower socioeconomic standing. Our results are useful, as they show us that there does exist a strong relationship between inter-class interaction and economic mobility and social connections for lower SES individuals. However, they make a very significant assumption, which is that exposure to high SES individuals as a low SES individual alone indicates social and economic mobility. When we look at the documentation of the 2 variables that we chose to compare, they specifically detail that ec_high_own_ses_college represents economic connectedness for high-SES individuals, while exposure_own_ses_college represents the mean exposure to high-SES individuals by college for low-SES individuals. Both of these variables, upon further inspection, already seem closely related to each other to begin with, as  inter-class engagement/interaction (ec_high_own_ses_college) and exposure to high SES individuals from low SES individuals (exposure_own_ses_college) are extremely comparable to each other. This could potentially also explain the strong linear relationship between the two when modeled, and might give us the false impression that there is a strong relationship when we’d actually need to look at more variables to determine so. If we were to explore this project any further we’d definitely take more care to closely examine the variables we had at our disposal. For example, it might be useful in the future to take a look at child economic connectedness levels within low SES and high SES groups. We could then compare those to parent or overall EC levels within the same groups to see whether or not any increases in economic connectedness over time might be related to increased exposure to high SES individuals.

# %% [markdown]
# ## Post-Analysis Reproducibility (10 points)
#
# You will need to make sure that your code can be run by another team and by us.  This will mean making sure that all steps run in sequence, and hopefully that all the datasets are easily read via file paths.
#
# We are anticipating that the easiest way to share will be via Google Colab. You are welcome to work on Datahub, on your local install, or any way you like.  However you will be expected to make sure that your complete notebook can run on Colab at the end of the project.  Please keep this in mind and save time to fiddle with things so it works!
#
#
# Please share your Google Colab (or equivalent) link in this [sheet](https://docs.google.com/spreadsheets/d/15oNmFwpjSHifnyPvJJ8Gv3ECNOPKHsIWvvt0EbkyXVU/edit?usp=sharing). Each group will be assigned another group's link randomly (in the same sheet) to review and run without issues. Please confirm and leave comments about issues about this in the sheet as well.
#
# This part is to ensure that we're building replicable and reusable code. Please refer to [section 9](https://docs.google.com/presentation/d/12eIuPKYZ8PMysm0pSxoClnh4YOQFRqHO6qVv2SN23Xc/edit?usp=share_link) for best practices of this.
